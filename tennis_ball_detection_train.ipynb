# %% [markdown]
# # Ball Detection

# %% [markdown]
# ## Install Torch and Ultralytics

# %%
# !pip install ultralytics

# %%
# !pip install torchvision==<compatible_version>
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `newline'
# /bin/bash: -c: line 1: `pip install torchvision==<compatible_version>'

# %%
import torch
import torchvision

print(torch.__version__)
print(torchvision.__version__)

print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU found")
# Out:
# 2.5.1+cu124
# 0.20.1+cu124
# True
# 1
# Tesla T4

# %% [markdown]
# ## Get Dataset

# %%
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="ylsx6V4srvlAuynfKUfG")
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to tennis-ball-detection-6 in yolov5pytorch:: 100%|██████████| 1168/1168 [00:00<00:00, 5466.68it/s]

# %%
import shutil

shutil.move("tennis-ball-detection-6/train",
"tennis-ball-detection-6/tennis-ball-detection-6/train",
)
shutil.move("tennis-ball-detection-6/test",
"tennis-ball-detection-6/tennis-ball-detection-6/test",
)
shutil.move("tennis-ball-detection-6/valid",
"tennis-ball-detection-6/tennis-ball-detection-6/valid",
)
# Out:
# 'tennis-ball-detection-6/tennis-ball-detection-6/valid'

# %% [markdown]
# ## Train

# %%
# !yolo task=detect mode=train model=yolov5l6u.pt data={dataset.location}/data.yaml epochs=2 imgsz=640
